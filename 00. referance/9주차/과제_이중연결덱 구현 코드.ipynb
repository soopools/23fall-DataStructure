# %%
MAX_QSIZE = 10
class circularQueue:
    def __Init__(self):
        self.front = 0
        self.rear = 0
        self.items = [None] * MAX_QSIZE
        
    def isEmpty(self): return self.front == self.rear
    def isFull(self): return self.front == (self.rear+1)%MAX_QSIZE
    
    def enque(self,item):
        if not self.isFull():
            self.rear = (self.rear+1)% MAX_QSIZE
            self.items[self.rear] = item
            
    def dequeue(self):
        if not self.isEmpty():
            self.front = (self.front+1) % MAX_QSIZE
            return self.items[self.front]
        
    def peek(self):
        if not self.isEmpty():
            return self.items[(self.front+1) % MAX_QSIZE]
        
    def size(self):
        return (self.rear - self.front + MAX_QSIZE) % MAX_QSIZE
    
    def dispaly(self):
        out = []
        if self.front < self.rear:
            out = self.items[self.front+1:self.rear+1]
        else:
            out = self.items[self.front+1:MAX_QSIZE] + self.items[0:self.rear+1]
            
        print( "[f=%d, r=%d] ==> " % (self.front, self.rear), out)

# %%
class CircularDeque(circularQueue):
    def __init__(self):
        super().__init__()
    
    def addRear(self, item): self.enqueue(item)
    def deleteFront(self): return self.dequeue()
    def getFront(self): return self.peek()
    def isEmpty(self) : return self.front == self.rear  #공백 상태
    def isfull(self) : return self.front == (self.rear +1) % MAX_QSIZE #포화 상태
    def size(self):
        return(self.rear - self.front + MAX_QSIZE) % MAX_QSIZE
    
    def addFront(self,item):
        if not self.ifFull():
            self.items[self.front] = item
            self.front = self.front -1 #반시계 방향으로 회전
            if self.front <0: self.front = MAX_QSIZE -1
                
    def deleteRear(self):
        if not self.isEmpty():
            item = self.item[self.rear];
            self.rear = self.rear -1 #반시계 방향으로 회전
            if self.rear < 0: self.rear = MAX_QSIZE -1
            return item
        
    def getRear(self):
        return self.items[self.rear]

# %%
class DNode:
    def __init__(self, elem, prev = None, next =None):
        self.data = elem
        self.prev = prev
        self.next = next
        
class DoublyLinkedDeque:
    def __init__(self):
        self.front = None
        self.rear = None
        
    def isEmpty(self): return self.front == None
    def clear(self): self.front = self.front = None
        
    def size(self):
        node = self.front
        count = 0
        while not node == None :
            node = node.next
            
    def display(self, msg = 'LinkedStack:'):
        print(msg, end='')
        node = self.front
        while node == None:
            print(node.data, end = '')
            node = node.next
        print()
        
    def addFront(self,item):
        node = DNode(item, None, self.front)
        if(self.isEmpty()):
            self.front = self.rear = node
        else:
            self.front.prev = node
            self.front = node
    
    def addRear(self, item):
        node = DNode(item,self.rear, None)
        if(self.isEmpty()):
            self.front = self.rear = node
            
        else:
            self.rear.next = node
            self.rear = node
            
    def deleteFront(self):
        if not self.isEmpty():
            data = self.front.data
            self.front = self.front.next
            if self.front == None:
                self.rear = None
                
            else:
                self.front.prev = None
            return data
        
    def deleteRear(self):
        if not self.isEmpty():
            data = self.rear.data
            self.rear == self.rear.prev
            if self.rear == None:
                self.front = None
            else:
                self.rear.next = None
                
            return data

# %%
class DNode:
    def __init__(self, elem, prev=None, next=None):
        self.data = elem
        self.prev = prev
        self.next = next

class DoublyLinkedDeque:
    def __init__(self):
        self.front = None
        self.rear = None

    def isEmpty(self):
        return self.front == None

    def clear(self):
        self.front = self.front = None

    def size(self):
        node = self.front
        count = 0
        while not node == None:
            node = node.next

    def display(self, msg='LinkedStack:'):
        print(msg, end='')
        node = self.front
        while node != None:
            print(node.data, end='')
            node = node.next
        print()

    def addFront(self, item):
        node = DNode(item, None, self.front)
        if (self.isEmpty()):
            self.front = self.rear = node
        else:
            self.front.prev = node
            self.front = node

    def addRear(self, item):
        node = DNode(item, self.rear, None)
        if (self.isEmpty()):
            self.front = self.rear = node
        else:
            self.rear.next = node
            self.rear = node

    def deleteFront(self):
        if not self.isEmpty():
            data = self.front.data
            self.front = self.front.next
            if self.front == None:
                self.rear = None

            else:
                self.front.prev = None
            return data
        else:
            return "underflow"

    def deleteRear(self):
        if not self.isEmpty():
            data = self.rear.data
            self.rear = self.rear.prev
            if self.rear == None:
                self.front = None
            else:
                self.rear.next = None

            return data

n = int(input("연산의 개수: "))
d = DoublyLinkedDeque()

for i in range(n):
    op = input().split()
    if op[0] == 'AF':
        d.addFront(int(op[1]))
    elif op[0] == 'AR':
        d.addRear(int(op[1]))
    elif op[0] == 'DF':
        print(d.deleteFront())
    elif op[0] == 'DR':
        print(d.deleteRear())

    d.display()
# Out:
# 연산의 개수: 7
# AF 10
# LinkedStack:10
# AF 20
# LinkedStack:2010
# AR 30
# LinkedStack:201030
# P
# LinkedStack:201030
# DF
# 20
# LinkedStack:1030
# DR
# 30
# LinkedStack:10
# P
# LinkedStack:10

# %%
class DNode:
    def __init__(self, elem, prev=None, next=None):
        self.data = elem
        self.prev = prev
        self.next = next

class DoublyLinkedDeque:
    def __init__(self):
        self.front = None
        self.rear = None

    def isEmpty(self):
        return self.front == None

    def clear(self):
        self.front = self.front = None

    def size(self):
        node = self.front
        count = 0
        while not node == None:
            node = node.next

    def display(self, msg='LinkedStack:'):
        print(msg, end='')
        node = self.front
        while node != None:
            print(node.data, end=' ')
            node = node.next
        print()

    def addFront(self, item):
        node = DNode(item, None, self.front)
        if (self.isEmpty()):
            self.front = self.rear = node
        else:
            self.front.prev = node
            self.front = node

    def addRear(self, item):
        node = DNode(item, self.rear, None)
        if (self.isEmpty()):
            self.front = self.rear = node
        else:
            self.rear.next = node
            self.rear = node

    def deleteFront(self):
        if not self.isEmpty():
            data = self.front.data
            self.front = self.front.next
            if self.front == None:
                self.rear = None
            else:
                self.front.prev = None
            return data
        else:
            print("underflow")

    def deleteRear(self):
        if not self.isEmpty():
            data = self.rear.data
            self.rear = self.rear.prev
            if self.rear == None:
                self.front = None
            else:
                self.rear.next = None
            return data
        else:
            print("underflow")

    
    def deleteRear(self):
        if not self.isEmpty():
            data = self.rear.data
            self.rear = self.rear.prev
            if self.rear == None:
                self.front = None
            else:
                self.rear.next = None
            return data
        else:
            print("underflow")



n = int(input("연산의 개수: "))
d = DoublyLinkedDeque()

for i in range(n):
    op = input().split()
    if op[0] == 'AF':
        d.addFront(int(op[1]))
    elif op[0] == 'AR':
        d.addRear(int(op[1]))
    elif op[0] == 'DF':
        print(d.deleteFront())
    elif op[0] == 'DR':
        data = d.deleteRear()
        if data != None:
            print(data)
        elif self.front == None or self.rear == None:
            
        
            
            print("underflow")
            break

    d.display()
# Out:
# 연산의 개수: 15
# AF 10
# LinkedStack:10
# AF 20
# LinkedStack:20 10
# AF 30
# LinkedStack:30 20 10
# AR 40
# LinkedStack:30 20 10 40
# AR 50
# LinkedStack:30 20 10 40 50
# P
# LinkedStack:30 20 10 40 50
# DF
# 30
# LinkedStack:20 10 40 50
# DF
# 20
# LinkedStack:10 40 50
# DR
# 50
# LinkedStack:10 40
# P
# LinkedStack:10 40
# DF
# 10
# LinkedStack:40
# DR
# 40
# LinkedStack:
# DR
# underflow
# None
# LinkedStack:
